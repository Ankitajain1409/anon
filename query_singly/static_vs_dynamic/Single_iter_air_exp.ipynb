# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = str(1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from dataloader import *
from model import *
from utilities import *
from retrain_fun4 import *
import random
random.seed(0)
np.random.seed(0)
jax.random.PRNGKey(0)
os.environ["XLA_FLAGS"] = "--xla_gpu_deterministic_reductions --xla_gpu_autotune_level=2"
os.environ['TF_CUDNN_DETERMINISTIC']='1'
# Out:
# 2023-06-23 21:31:05.382457: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data_aggregated, houses = data_preprocess(only_positive=True)

# %% [markdown]
# Train: [2361, 7719, 9019, 2335, 7951]
# Test:  [4373, 7901, 3456, 3538, 2818]

# %%
train_list= [[2361, 7719, 9019, 2335, 7951]]
test_list= [[4373, 7901, 3456, 3538, 2818]]
pool_list=[]
for i in range(len(train_list)):
    pool = [j for j in houses if j not in train_list[i]+test_list[i]]
    pool_list.append(pool)

# %%
appliance = 'clotheswasher'

# %%
pool_list
# Out:
# [[5746, 8565, 9278, 8156, 8386, 9160, 661, 1642, 7536, 7800]]

# %%
total_rmse=[]
total_mae = []
houseids=[]
for i in range(len(train_list)):
    # print(len(train_list))
    print("Train Set No:", i+1)
    train_houses = train_list[i]
    test_houses = test_list[i]
    pool_houses = pool_list[i]
    train = data_aggregated[data_aggregated["dataid"].isin(train_houses)] 
    test = data_aggregated[data_aggregated["dataid"].isin(test_houses)]

    
    rmse_iter=[]
    mae_iter = []
    houses=[]
    start= ["2018-03-01 00:00:00-06","2018-03-11 00:00:00-06", "2018-03-16 00:00:00-06", "2018-03-21 00:00:00-06", "2018-03-26 00:00:00-06", "2018-04-01 00:00:00-06","2018-04-06 00:00:00-06","2018-04-11 00:00:00-06","2018-04-16 00:00:00-06","2018-04-21 00:00:00-06"]
    end= ["2018-03-10 23:59:00-06","2018-03-15 23:59:00-06","2018-03-20 23:59:00-06","2018-03-25 23:59:00-06","2018-03-31 23:59:00-06","2018-04-05 23:59:00-06", "2018-04-10 23:59:00-06", "2018-04-15 23:59:00-06", "2018-04-20 23:59:00-06", "2018-04-25 23:59:00-06"]
    for j in range(len(start)):
        # print(len(start))
        print("Iteration No: ",j)
        if(j==0):
            house, houseid,rmsee, train, test, maee= retrain(0, start[j], end[j], pool_houses, train, test, appliance, data_aggregated)
            rmse_iter.append(rmsee.item())
            mae_iter.append(maee.item())
            houses.append(house)
            pool_houses= np.delete(pool_houses, houseid)
        elif(j==10):
            house, houseid,rmsee, train, test, maee= retrain(house, start[j], end[j], pool_houses, train, test, appliance, data_aggregated)
            rmse_iter.append(rmsee.item())
            mae_iter.append(maee.item())
        else:
            house, houseid,rmsee, train, test, maee= retrain(house, start[j], end[j], pool_houses, train, test, appliance, data_aggregated)
            rmse_iter.append(rmsee.item())
            mae_iter.append(maee.item())
            houses.append(house)
            pool_houses= np.delete(pool_houses, houseid)
    total_rmse.append(rmse_iter)
    total_mae.append(mae_iter)
    houseids.append(houses)
# Out:
# Train Set No: 1
# Iteration No:  0
# (10, 58739, 1)
# RMSE : 80.3158 MAE  : 46.4278 NLL : 5.7735
# 2023-06-23 21:32:22.747587: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[184660,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[184660,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:32:26.274145: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[165830,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[165830,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:32:29.548309: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[159720,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[159720,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:32:32.797549: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[159470,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[159470,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:32:38.832799: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[158870,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[158870,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:32:42.489208: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[184760,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[184760,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:32:46.077800: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[185150,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[185150,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:32:49.528847: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[162210,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[162210,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# Iteration No:  1
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278]
# RMSE : 64.0465 MAE  : 38.6016 NLL : 5.3600
# Iteration No:  2
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642]
# 2023-06-23 21:33:22.679300: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[118265,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[118265,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:33:23.595866: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[118265,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[118265,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 57.4326 MAE  : 31.2661 NLL : 5.5015
# Iteration No:  3
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642 8156]
# 2023-06-23 21:33:58.047981: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[166526,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[166526,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:33:58.935787: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[166526,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[166526,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:34:00.025660: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[166526,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[166526,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:34:01.172539: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[166526,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[166526,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 55.5148 MAE  : 29.8633 NLL : 5.7164
# Iteration No:  4
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642 8156 8565]
# 2023-06-23 21:34:34.273952: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[231621,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[231621,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:34:35.450870: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[231621,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[231621,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:34:36.852122: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[231621,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[231621,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:34:38.378874: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[231621,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[231621,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 54.0855 MAE  : 29.0202 NLL : 5.7980
# Iteration No:  5
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642 8156 8565 7800]
# 2023-06-23 21:35:17.890758: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[291652,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[291652,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:35:19.345626: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[291652,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[291652,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:35:21.047387: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[291652,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[291652,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:35:22.914700: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[291652,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[291652,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 53.7636 MAE  : 28.4631 NLL : 5.9710
# Iteration No:  6
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642 8156 8565 7800  661]
# 2023-06-23 21:36:09.483206: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[357621,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[357621,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:36:11.241695: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[357621,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[357621,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:36:13.258009: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[357621,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[357621,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:36:15.508301: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[357621,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[357621,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 52.9751 MAE  : 27.5115 NLL : 5.7310
# Iteration No:  7
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642 8156 8565 7800  661 7536]
# 2023-06-23 21:37:08.596883: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[431607,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[431607,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:37:10.677492: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[431607,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[431607,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 52.0895 MAE  : 26.8155 NLL : 5.6507
# Iteration No:  8
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642 8156 8565 7800  661 7536 8386]
# 2023-06-23 21:38:15.808938: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[511964,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[511964,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:38:18.245890: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[511964,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[511964,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 51.1786 MAE  : 26.0081 NLL : 5.3845
# Iteration No:  9
# /home/dhruv.patel/final_active/static/retrain_fun4.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 9278 1642 8156 8565 7800  661 7536 8386 9160]
# 2023-06-23 21:39:33.669257: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[596626,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[596626,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-06-23 21:39:36.477221: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[596626,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[596626,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 49.9002 MAE  : 24.9791 NLL : 5.3788

# %%
houseids
# Out:
# [[9278, 1642, 8156, 8565, 7800, 661, 7536, 8386, 9160, 5746]]

# %%
total_rmse
# Out:
# [[80.31578826904297,
#   64.0465316772461,
#   57.4326286315918,
#   55.514835357666016,
#   54.08552932739258,
#   53.763648986816406,
#   52.97513961791992,
#   52.08953094482422,
#   51.17858123779297,
#   49.90024948120117]]

# %%
d = pd.DataFrame(total_rmse)
d2 = pd.DataFrame(total_mae)
house_df= pd.DataFrame(houseids)
if not os.path.exists(f'{appliance}'):
    os.mkdir(f'{appliance}')

# Save the DataFrame to a CSV file
d.to_csv(os.path.join(f'{appliance}', "04errors_rmse.csv"), index=False)
d2.to_csv(os.path.join(f'{appliance}', "04errors_mae.csv"), index=False)
house_df.to_csv(os.path.join(f'{appliance}', "04houseids.csv"), index=False)

# %%
plt.plot(total_rmse[0])
plt.xlabel("#Iterations")
plt.ylabel("RMSE")
plt.title("air")
# Out:
# Text(0.5, 1.0, 'air')
